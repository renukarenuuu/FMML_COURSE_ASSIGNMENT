# %% [markdown]
# <a href="https://colab.research.google.com/github/renukarenuuu/FMML_COURSE_ASSIGNMENT/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-10 04:12:29--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   215MB/s    in 0.3s
#
# 2022-06-10 04:12:31 (215 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11591  1606.09184v1  Medical researchers are coming to appreciate t...  stat
# 8621   1707.09240v2  Human pose forecasting is an important problem...    cs
# 19072   1304.0897v1  We describe a duality mapping between STRIPS p...    cs
# 30984  1802.00421v1  In this paper, we propose efficient method whi...    cs
# 31167  1802.06130v1  Denoising is a fundamental imaging problem. Ve...    cs
# ...             ...                                                ...   ...
# 13939  1609.02053v1  Biological neurons communicate with a sparing ...    cs
# 6504   1702.08540v1  Many active learning methods belong to the ret...  stat
# 10750   1401.3258v1  Learning the right graph representation from n...    cs
# 11412  1601.02068v6  We derive computationally tractable methods to...  stat
# 31444  1803.04108v4  Recent advances in facial landmark detection a...    cs
#
#                                                    title  year  \
# 11591                            Disease Trajectory Maps  2016
# 8621       Human Pose Forecasting via Deep Markov Models  2017
# 19072                         Duality in STRIPS planning  2013
# 30984  A Fusion of Appearance based CNNs and Temporal...  2018
# 31167              Fast, Trainable, Multiscale Denoising  2018
# ...                                                  ...   ...
# 13939  Fast and Efficient Asynchronous Neural Computa...  2016
# 6504       Active Learning Using Uncertainty Information  2017
# 10750  A Boosting Approach to Learning Graph Represen...  2014
# 11412  On Computationally Tractable Selection of Expe...  2016
# 31444  Style Aggregated Network for Facial Landmark D...  2018
#
#                                                 keywords
# 11591  [researchers, appreciate, heterogeneous, syndr...
# 8621   [forecasting, important, applications, interac...
# 19072  [exchanging, conditions, respective, complemen...
# 30984  [efficient, information, appearance, recogniti...
# 31167  [denoising, fundamental, versatile, filtering,...
# ...                                                  ...
# 13939  [biological, communicate, computation, artific...
# 6504   [retraining, approaches, unlabeled, classifica...
# 10750  [representation, multisource, significant, rel...
# 11412  [computationally, tractable, experiment, regre...
# 31444  [detection, discriminative, deformation, thems...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11591    [researchers, appreciate, heterogeneous, syndr...
# 8621     [forecasting, important, applications, interac...
# 19072    [exchanging, conditions, respective, complemen...
# 30984    [efficient, information, appearance, recogniti...
# 31167    [denoising, fundamental, versatile, filtering,...
#                                ...
# 6767     [approaches, significant, potential, reinforce...
# 4707     [analogical, dissimilarity, structured, sequen...
# 13902    [objective, optimization, algorithm, achieving...
# 22268    [framework, streaming, covariance, selection, ...
# 7030     [supervised, clustering, knowledge, interactiv...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8696 words.
# Out of those 4597 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="faed0a49-caab-4e2b-8c47-865c5b8a8127" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("faed0a49-caab-4e2b-8c47-865c5b8a8127")) {                    Plotly.newPlot(                        "faed0a49-caab-4e2b-8c47-865c5b8a8127",                        [{"x":["population","trajectories","different","complication","representations","researchers","stochastic","irregularly","heterogeneous","databases","trajectory","differences","subpopulations","important","questions","dimensional","autoimmune","individual","probabilistic","inference","scleroderma","associated","meaningful","electronic","algorithm","extracted","demonstrate","collected","answering","appreciate","variational","individuals","significantly","understand","introduce","algorithms","furniture","surveillance","contributions","repeatedly","evaluation","forecasting","interaction","estimating","framework","classifier","difficulty","applications","continues","threefold","autoencoders","challenging","coordinate","milliseconds","forecasts","subjective","promising","sequences","autonomous","generative","assembling","exchanging","challenge","essentially","complements","transformation","difficult","regression","benchmarks","conditions","described","experiments","progression","construct","respective","achieving","information","especially","recognition","available","evolution","efficient","appearance","footprint","magnitude","experimental","presented","structure","trainable","comparable","denoising","multiscale","filtering","processing","versatile","fundamental","artifacts","comparison","estimation","empirical","distribution","independent","assumptions","benchmark","sublinear","dependency","stationary","impossible","estimators","observations","complexity","memoryless","synthetic","relaxation","perplexity","reversible","consistent","achievable","prototypical","dimensions","numerical","estimator","simulated","investigated","aggregation","precision","underlying","exponential","screening","graphical","performance","procedures","variables","predictive","statistically","temperature","dictionary","uncertainty","probability","posterior","specified","dependencies","geometric","generalize","previously","adversarial","experiment","reinforcement","technique","frequency","possibility","intercept","multivariate","sensitive","expectations","classification","developed","compression","treatment","deterministic","processed","supervised","parameters","modulation","modulated","clustering","generalized","restrictive","characterized","sensitivity","initialization","waveforms","introduction","remarkably","resources","carpentier","allocating","contribution","sequentially","approaches","classical","alternative","empirically","iterations","requirement","adversarially","flexibility","formulate","advantage","inpainting","guaranteed","simplicity","generation","attribute","procedure","undirected","iterative","prediction","thousands","gradually"],"y":[63,29,761,1,242,80,137,2,40,57,26,58,1,375,66,182,1,134,148,212,0,90,42,13,827,123,542,55,62,0,51,31,252,91,321,627,3,31,47,11,243,16,79,60,521,126,50,434,8,2,17,275,15,4,6,29,96,92,65,115,3,4,155,25,6,55,150,94,84,149,79,609,8,91,20,82,690,133,389,302,69,437,74,9,65,371,188,353,27,95,36,13,70,284,7,87,17,132,227,148,207,132,63,227,7,50,30,15,22,75,223,4,119,20,5,5,85,10,4,41,76,21,51,46,26,82,108,38,11,51,898,37,92,57,26,5,46,82,173,38,38,49,72,52,99,85,79,129,252,60,36,0,22,57,7,483,187,56,25,36,32,207,234,4,4,121,63,8,29,24,24,5,36,12,67,1,3,90,15,442,81,79,74,22,29,5,31,54,84,8,26,18,154,32,118,13,80,230,29,13],"type":"bar"},{"x":["population","trajectories","different","complication","representations","researchers","stochastic","irregularly","heterogeneous","databases","tra ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4597,), (4597, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Can</span> <span style=''>Autism</span> <span style=''>be</span> <span style=''>Catered</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.4736842105263157);'>Artificial</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333333);'>Intelligence</span> <span style=''>Assisted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Intervention</span> <span style='background-color:rgba(0, 255, 0, 0.6438356164383561);'>Technology</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Literature</span> <span style=''>Review</span> <br/><br/><span style=''>This</span> <span style=''>article</span> <span style=''>presents</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>review</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6438356164383561);'>technology</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intervention</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodologies</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individuals</span> <span style=''>facing</span> <span style=''>Autism</span> <span style=''>Spectrum</span> <span style=''>Disorder</span> <span style=''>(ASD)</span> <span style=''>Reviewed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodologies</span> <span style=''>include</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contemporary</span> <span style=''>Computer</span> <span style=''>Aided</span> <span style=''>Systems</span> <span style=''>(CAS)</span> <span style=''>Computer</span> <span style=''>Vision</span> <span style=''>Assisted</span> <span style='background-color:rgba(0, 255, 0, 0.7826086956521738);'>Technologies</span> <span style=''>(CVAT)</span> <span style=''>and</span> <span style=''>Virtual</span> <span style=''>Reality</span> <span style=''>(VR)</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.4736842105263157);'>Artificial</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333333);'>Intelligence</span> <span style=''>Assisted</span> <span style='background-color:rgba(255, 0, 0, 0.5454545454545455);'>interventions</span> <span style=''>The</span> <span style=''>research</span> <span style=''>over</span> <span style=''>the</span> <span style=''>past</span> <span style=''>decade</span> <span style=''>has</span> <span style=''>provided</span> <span style=''>enough</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>demonstrations</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individuals</span> <span style=''>of</span> <span style=''>ASD</span> <span style=''>have</span> <span style=''>a</span> <span style=''>strong</span> <span style=''>interest</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.6438356164383561);'>technology</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.5454545454545455);'>interventions</span> <span style=''>and</span> <span style=''>can</span> <span style=''>connect</span> <span style=''>with</span> <span style=''>them</span> <span style=''>for</span> <span style=''>longer</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>durations</span> <span style=''>without</span> <span style=''>facing</span> <span style=''>any</span> <span style=''>trouble(s)</span> <span style=''>Theses</span> <span style='background-color:rgba(0, 255, 0, 0.6438356164383561);'>technology</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.5454545454545455);'>interventions</span> <span style=''>are</span> <span style=''>useful</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>of</span> <span style=''>SDCA</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinate</span> <span style=''>(SDCA)</span> <span style=''>em</span> <span style=''>without</span> <span style=''>strongly</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>or</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>SDCA</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>linearly</span> <span style=''>under</span> <span style=''>mild</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>termed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricted</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convexity</span> <span style=''>This</span> <span style=''>covers</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>array</span> <span style=''>of</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>Lasso</span> <span style=''>group</span> <span style=''>Lasso</span> <span style=''>and</span> <span style=''>logistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>with</span> <span style=''>ell</span> <span style=''>1</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corrected</span> <span style=''>Lasso</span> <span style=''>and</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>with</span> <span style=''>SCAD</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>improves</span> <span style=''>previous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>results</span> <span style=''>on</span> <span style=''>SDCA</span> <span style=''>for</span> <span style=''>problems</span> <span style=''>that</span> <span style=''>are</span> <span style=''>not</span> <span style=''>strongly</span> <span style=''>convex</span> <span style=''>As</span> <span style=''>a</span> <span style=''>by</span> <span style=''>product</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>dual</span> <span style=''>free</span> <span style=''>form</span> <span style=''>of</span> <span style=''>SDCA</span> <span style=''>that</span> <span style=''>can</span> <span style=''>handle</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>term</span> <span style=''>which</span> <span style=''>is</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>by</span> <span style=''>itself</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style=''>Online</span> <span style=''>Learning</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.5238095238095237);'>Truncated</span> <span style=''>Gradient</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style=''>method</span> <span style=''>called</span> <span style='background-color:rgba(255, 0, 0, 0.5238095238095237);'>truncated</span> <span style=''>gradient</span> <span style=''>to</span> <span style=''>induce</span> <span style=''>sparsity</span> <span style=''>in</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>convex</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>This</span> <span style=''>method</span> <span style=''>has</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.38636363636363635);'>essential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>The</span> <span style=''>degree</span> <span style=''>of</span> <span style=''>sparsity</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>controls</span> <span style=''>the</span> <span style=''>rate</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454546);'>sparsification</span> <span style=''>from</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454546);'>sparsification</span> <span style=''>to</span> <span style=''>total</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454546);'>sparsification</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivated</span> <span style=''>and</span> <span style=''>an</span> <span style=''>instance</span> <span style=''>of</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style=''>regarded</span> <span style=''>as</span> <span style=''>an</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>counterpart</span> <span style=''>of</span> <span style=''>the</span> <span style=''>popular</span> <span style=''>L</span> <span style=''>1</span> <span style='background-color:rgba(255, 0, 0, 0.3670886075949367);'>regularization</span> <span style=''>method</span> <span style=''>in</span> <span style=''>the</span> <span style=''>batch</span> <span style=''>setting</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>small</span> <span style=''>rates</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4545454545454546);'>sparsification</span> <span style=''>result</span> <span style=''>in</span> <span style=''>only</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>regret</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>typical</span> <span style=''>online</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.33742331288343563);'>guarantees</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>works</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirically</span> <span style=''>We</span> <span style=''>apply</span> <span style=''>the</span> <span style=''>ap ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Improving</span> <span style=''>Power</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficiency</span> <span style=''>using</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Recently</span> <span style=''>there</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>research</span> <span style=''>on</span> <span style=''>power</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transmission</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>renewable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resources</span> <span style=''>The</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>of</span> <span style=''>energy</span> <span style=''>losses</span> <span style=''>and</span> <span style=''>this</span> <span style=''>requires</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvements</span> <span style=''>on</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style=''>and</span> <span style=''>analysis</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>these</span> <span style=''>concerns</span> <span style=''>by</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consumers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>electrical</span> <span style=''>smart</span> <span style=''>meter</span> <span style=''>readings</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>network</span> <span style=''>loading</span> <span style=''>and</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>can</span> <span style=''>then</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style=''>better</span> <span style=''>capacity</span> <span style=''>planning</span> <span style=''>We</span> <span style=''>compare</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>(DNN)</span> <span style=''>methods</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>load</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>indicate</span> <span style=''>that</span> <span style=''>DNN</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperform</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>methods</span> <span style=''>This</span> <span style=''>comes</span> <span style=''>at</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(0 ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13193456614509247)
# 	knowledge (0.12695590327169273)
# 	architecture (0.08783783783783784)
# 	information (0.2453769559032717)
# 	representation (0.1287339971550498)
# 	detection (0.11130867709815079)
# 	segmentation (0.07076813655761025)
# 	different (0.2706258890469417)
# 	convolutional (0.14331436699857752)
# 	recognition (0.13833570412517782)
#
# Some Statistics words are:
# 	statistical (0.14738430583501005)
# 	algorithm (0.3858148893360161)
# 	stochastic (0.14084507042253522)
# 	theoretical (0.14989939637826963)
# 	estimation (0.17857142857142858)
# 	distribution (0.17404426559356137)
# 	variables (0.1403420523138833)
# 	dimensional (0.1891348088531187)
# 	inference (0.20271629778672032)
# 	regression (0.18611670020120724)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="353b3c56-503d-42ed-ab12-8d392abbec08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("353b3c56-503d-42ed-ab12-8d392abbec08")) {                    Plotly.newPlot(                        "353b3c56-503d-42ed-ab12-8d392abbec08",                        [{"x":["population","trajectories","different","complication","representations","researchers","stochastic","irregularly","heterogeneous","databases","trajectory","differences","subpopulations","important","questions","dimensional","autoimmune","individual","probabilistic","inference","scleroderma","associated","meaningful","electronic","algorithm","extracted","demonstrate","collected","answering","appreciate","variational","individuals","significantly","understand","introduce","algorithms","furniture","surveillance","contributions","repeatedly","evaluation","forecasting","interaction","estimating","framework","classifier","difficulty","applications","continues","threefold","autoencoders","challenging","coordinate","milliseconds","forecasts","subjective","promising","sequences","autonomous","generative","assembling","exchanging","challenge","essentially","complements","transformation","difficult","regression","benchmarks","conditions","described","experiments","progression","construct","respective","achieving","information","especially","recognition","available","evolution","efficient","appearance","footprint","magnitude","experimental","presented","structure","trainable","comparable","denoising","multiscale","filtering","processing","versatile","fundamental","artifacts","comparison","estimation","empirical","distribution","independent","assumptions","benchmark","sublinear","dependency","stationary","impossible","estimators","observations","complexity","memoryless","synthetic","relaxation","perplexity","reversible","consistent","achievable","prototypical","dimensions","numerical","estimator","simulated","investigated","aggregation","precision","underlying","exponential","screening","graphical","performance","procedures","variables","predictive","statistically","temperature","dictionary","uncertainty","probability","posterior","specified","dependencies","geometric","generalize","previously","adversarial","experiment","reinforcement","technique","frequency","possibility","intercept","multivariate","sensitive","expectations","classification","developed","compression","treatment","deterministic","processed","supervised","parameters","modulation","modulated","clustering","generalized","restrictive","characterized","sensitivity","initialization","waveforms","introduction","remarkably","resources","carpentier","allocating","contribution","sequentially","approaches","classical","alternative","empirically","iterations","requirement","adversarially","flexibility","formulate","advantage","inpainting","guaranteed","simplicity","generation","attribute","procedure","undirected","iterative","prediction","thousands","gradually","expressiveness","refinement","conditional","generally","correspondence","restricted","statistical","outperforming","direction","boltzmann","guarantees","improving","divergence","indicating","contrastive","irrelevant","specifically","application","theoretical","nonlinear","phenomenon","multimodal","modalities","assessment","correlated","attention","particularly","components","variability","measurements","knowledge","additional","significant","representation","particular","diffusion","presenting","consisting","intrinsic","improvement","implemented","utilizing","irregular","unfolding","projection","reference","efficiency","characteristic","relationship","generalizes","annotations","corresponding","superpixels","programming","segmentation","additionally","homogeneous","quantitative","par ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	scleroderma
# 	appreciate
# 	intercept
# 	unidentifiability
# 	forecasted
# 	deteriorates
# 	nesterovs
# 	strikingly
# 	marginalization
# 	regressionclassification
# 	nonconjugate
# 	prognostic
# 	expecting
# 	marginalised
# 	temperatures
# 	transplantation
# 	gaussianity
# 	trilinear
# 	perturbative
# 	cumulants
# Some words which never appear in Statistics papers:
# 	furniture
# 	continues
# 	milliseconds
# 	exchanging
# 	memoryless
# 	evidences
# 	silhouettes
# 	binarized
# 	inherited
# 	accomplishing
# 	reflective
# 	discipline
# 	bilingual
# 	rethinking
# 	reprojection
# 	grammatically
# 	paraphrases
# 	paraphrase
# 	managements
# 	inventories

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0565149616407374e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7683333333333333
